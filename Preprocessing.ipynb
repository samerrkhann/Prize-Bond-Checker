# %% [markdown]
# # Preprocessing Pipeline

# %%
from urllib.request import urlopen
import re
import pandas as pd
import numpy as np
import os

# %%
def date_fixer(x):
    return x[:2]+'-'+x[2:4]+'-'+x[4:8]

def pipeline(url):
    #to aid in imputing the values that do not change
    map_dict = {'100':[4,700000,200000,1000,1203],'200':[6,750000,250000,1250,2400],
     '750':[4,1500000,500000,9300,1700],'1500':[4,3000000,1000000,18500,1700],
     '7500':[4,15000000,5000000,93000,1700]}
    
    #TO READ THE FILE
    f = urlopen(url) #to link towards the URL
    my_file = f.read() #to read the lines
    s=str(my_file) #convert into string
    ss=s.split('\\n') #for parsing

    #TO FORMAT THE DETAILS TO BE EXTRACTED
    det_ph = [] #place holder list for the details reagrding the draw
    for i in ss[:32]: #since we only need details
        ## fresh list
        new_lst=[]
        for n in i:
            try:
                #to make sure only the numerical values pass by
                ii = int(n)
                new_lst.append(n) #append the filtered numerical values
            except:
                pass
        if len(new_lst)>0: #to delete empty lists
            det_ph.append(''.join(new_lst)) #to join all entries of a single line
    
    #TO EXTRACT USEFUL DETAILS
    den = det_ph[0] #denomination
    draw_num = det_ph[1] #draw number
    date = det_ph[2] #date of the draw
    fst_pr = map_dict[den][1] #first price
    sec_pr = map_dict[den][2] #second price
    trd_pr = map_dict[den][3] #third price

    #TO EXTRACT WINNING NUMBERS
    jnd = [] #another fresh list
    for i in ss:
        sp = i.split('\\t') #to extract the numbers
        new_lst=[]
        for n in sp:
            split = np.array(n.replace('\\r',' ').split())
            for n2 in split: 
                try:
                    check = n2.astype(np.uint32)
                    if len(n2) >5:
                        new_lst.append(n2)
                except:
                    pass
        if len(new_lst)>0:
            jnd.append(new_lst)
    num=[]
    for f in jnd:
        for s in f:
            if len(s)>5:
                num.append(s)  
    
    #TO COMPILE THE DATA INTO FRAME
    df=pd.DataFrame(num,columns=['Bond No.']) #to create an empty frame
    ind = map_dict[den][0] #this will map the indices to extract second prize winners
    df['Price'] = '' #create an empty price column
    df.iloc[0,1] = 'first' #fill the values
    df.iloc[1:ind,1] = 'second'
    df.iloc[ind:,1] = 'third'
    df['Amount'] = '' #create empty amount column
    df.iloc[0,2] = fst_pr #fill the values
    df.iloc[1:ind,2] = sec_pr
    df.iloc[ind:,2] = trd_pr
    df['Denomination'] = den
    df['Draw No.'] = draw_num
    df['Draw date'] = date
    df['Draw date']=df['Draw date'].apply(lambda x : date_fixer(x))
    df = df[df['Bond No.'] != '000000']
    
    #TO FIX MORE FORMATTING RELATED ISSUES
    if not len(df) == map_dict[den][4]:
        mdf = pd.DataFrame().reindex_like(df).iloc[:ind,:]
        mdf.iloc[0,0] = det_ph[4]
        mdf.iloc[1:,0] = [det_ph[6][6*(i):6*(i+1)] for i in range(len(det_ph[6])//6)]
        mdf.iloc[0,1] = 'first'
        mdf.iloc[1:,1] = 'second'
        mdf.iloc[0,2] = fst_pr
        mdf.iloc[1:,2] = sec_pr
        mdf.iloc[:,3] = den
        mdf.iloc[:,4] = draw_num
        mdf.iloc[:,5] = date
        df.iloc[:,1] = 'third'
        df = pd.concat([mdf,df])
    return df

# %%
with open('link_lst.txt') as f: #to go through all the links one by one
    r = f.read().split('\n')

# %%
dff = pd.DataFrame(columns=['Bond No.', 'Price', 'Amount', 'Denomination', 'Draw No.', 'Draw date'])
#to make one dataframe with complete data
for c,u in enumerate(r):
    d = pipeline(u)
    print('Joined',c+1,'Frame','the last denomination was',d.iloc[0,3])
    dff = pd.concat([dff,d])
# Out:
# Joined 1 Frame the last denomination was 100
# Joined 2 Frame the last denomination was 100
# Joined 3 Frame the last denomination was 100
# Joined 4 Frame the last denomination was 100
# Joined 5 Frame the last denomination was 100
# Joined 6 Frame the last denomination was 100
# Joined 7 Frame the last denomination was 100
# Joined 8 Frame the last denomination was 100
# Joined 9 Frame the last denomination was 100
# Joined 10 Frame the last denomination was 100
# Joined 11 Frame the last denomination was 100
# Joined 12 Frame the last denomination was 100
# Joined 13 Frame the last denomination was 100
# Joined 14 Frame the last denomination was 100
# Joined 15 Frame the last denomination was 100
# Joined 16 Frame the last denomination was 100
# Joined 17 Frame the last denomination was 100
# Joined 18 Frame the last denomination was 100
# Joined 19 Frame the last denomination was 100
# Joined 20 Frame the last denomination was 100
# Joined 21 Frame the last denomination was 100
# Joined 22 Frame the last denomination was 100
# Joined 23 Frame the last denomination was 100
# Joined 24 Frame the last denomination was 100
# Joined 25 Frame the last denomination was 200
# Joined 26 Frame the last denomination was 200
# Joined 27 Frame the last denomination was 200
# Joined 28 Frame the last denomination was 200
# Joined 29 Frame the last denomination was 200
# Joined 30 Frame the last denomination was 200
# Joined 31 Frame the last denomination was 200
# Joined 32 Frame the last denomination was 200
# Joined 33 Frame the last denomination was 200
# Joined 34 Frame the last denomination was 200
# Joined 35 Frame the last denomination was 200
# Joined 36 Frame the last denomination was 200
# Joined 37 Frame the last denomination was 200
# Joined 38 Frame the last denomination was 200
# Joined 39 Frame the last denomination was 200
# Joined 40 Frame the last denomination was 200
# Joined 41 Frame the last denomination was 200
# Joined 42 Frame the last denomination was 200
# Joined 43 Frame the last denomination was 200
# Joined 44 Frame the last denomination was 200
# Joined 45 Frame the last denomination was 200
# Joined 46 Frame the last denomination was 200
# Joined 47 Frame the last denomination was 200
# Joined 48 Frame the last denomination was 200
# Joined 49 Frame the last denomination was 750
# Joined 50 Frame the last denomination was 750
# Joined 51 Frame the last denomination was 750
# Joined 52 Frame the last denomination was 750
# Joined 53 Frame the last denomination was 750
# Joined 54 Frame the last denomination was 750
# Joined 55 Frame the last denomination was 750
# Joined 56 Frame the last denomination was 750
# Joined 57 Frame the last denomination was 750
# Joined 58 Frame the last denomination was 750
# Joined 59 Frame the last denomination was 750
# Joined 60 Frame the last denomination was 750
# Joined 61 Frame the last denomination was 750
# Joined 62 Frame the last denomination was 750
# Joined 63 Frame the last denomination was 750
# Joined 64 Frame the last denomination was 750
# Joined 65 Frame the last denomination was 750
# Joined 66 Frame the last denomination was 750
# Joined 67 Frame the last denomination was 750
# Joined 68 Frame the last denomination was 750
# Joined 69 Frame the last denomination was 750
# Joined 70 Frame the last denomination was 750
# Joined 71 Frame the last denomination was 750
# Joined 72 Frame the last denomination was 750
# Joined 73 Frame the last denomination was 750
# Joined 74 Frame the last denomination was 1500
# Joined 75 Frame the last denomination was 1500
# Joined 76 Frame the last denomination was 1500
# Joined 77 Frame the last denomination was 1500
# Joined 78 Frame the last denomination was 1500
# Joined 79 Frame the last denomination was 1500
# Joined 80 Frame the last denomination was 1500
# Joined 81 Frame the last denomination was 1500
# Joined 82 Frame the last denomination was 1500
# Joined 83 Frame the last denomination was 1500
# Joined 84 Frame the last denomination was 1500
# Joined 85 Frame the last denomination was 1500
# Joined 86 Frame the last denomination was 1500
# Joined 87 Frame the last denomination was 1500
# Joined 88 Frame the last denomination was 1500
# Joined 89 Frame the last denomination was 1500
# Joined 90 Frame the last denomination was 1500
# Joined 91 Frame the last denomination was 1500
# Joined 92 Frame the last denomination was 1500
# Joined 93 Frame the last denomination was 1500
# Joined 94 Frame the last denomination was 1500
# Joined 95 Frame the last denomination was 1500
# Joined 96 Frame the last denomination was 1500
# Joined 97 Frame the last denomination was 1500
# Joined 98 Frame the last denomination was 7500
# Joined 99 Frame the last denomination was 7500
# Joined 100 Frame the last denomination was 7500
# Joined 101 Frame the last denomination was 7500
# Joined 102 Frame the last denomination was 7500
# Joined 103 Frame the last denomination was 7500
# Joined 104 Frame the last denomination was 7500
# Joined 105 Frame the last denomination was 7500
# Joined 106 Frame the last denomination was 7500
# Joined 107 Frame the last denomination was 7500
# Joined 108 Frame the last denomination was 7500
# Joined 109 Frame the last denomination was 7500
# Joined 110 Frame the last denomination was 7500
# Joined 111 Frame the last denomination was 7500
# Joined 112 Frame the last denomination was 7500
# Joined 113 Frame the last denomination was 7500
# Joined 114 Frame the last denomination was 7500
# Joined 115 Frame the last denomination was 7500
# Joined 116 Frame the last denomination was 7500
# Joined 117 Frame the last denomination was 7500
# Joined 118 Frame the last denomination was 7500

# %%
dff.to_csv('data.csv')
## with this, the process of data collection is completed
